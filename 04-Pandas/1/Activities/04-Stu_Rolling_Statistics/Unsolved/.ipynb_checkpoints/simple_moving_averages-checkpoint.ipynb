# %% [markdown]
# ### Instructor Demo: Simple Moving Averages
#
# This program reads in the CSV datasets of Netflix (NFLX) and plots the 20, 50, and 100 Simple Moving Averages (SMA) using the `rolling` function, `window` parameter, and `mean` function.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path
filepath = "../Resources/nflx.csv"
# Read the CSV into a DataFrame and set the 'date' column as a datetime index
df = pd.read_csv(filepath,index_col="date",parse_dates=True,infer_datetime_format=True)
df.sort_index(inplace=True)
# Display a few records
df.head()
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame
df.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
SMA20 = df.rolling(window=20).mean()
SMA20
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# ...              ...
# 2019-05-10  368.6880
# 2019-05-13  368.3940
# 2019-05-14  368.2310
# 2019-05-15  368.0075
# 2019-05-16  368.2360
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices
SMA50 = df.rolling(window=50).mean()
SMA50
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# ...              ...
# 2019-05-10  364.3480
# 2019-05-13  364.1068
# 2019-05-14  363.9982
# 2019-05-15  364.0120
# 2019-05-16  364.0060
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
SMA100 = df.rolling(window=100).mean()
SMA100
# Out:
#                 close
# date
# 2009-05-18        NaN
# 2009-05-19        NaN
# 2009-05-20        NaN
# 2009-05-21        NaN
# 2009-05-22        NaN
# ...               ...
# 2019-05-10  343.90385
# 2019-05-13  344.72845
# 2019-05-14  345.47515
# 2019-05-15  346.35735
# 2019-05-16  347.34465
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
# Set figure of the daily closing prices of NFLX
plt.figure()
df["close"].plot()

# Overlay SMA20, SMA50, and SMA100 on the same figure
SMA20["close"].plot()
SMA50["close"].plot()
SMA100["close"].plot()

# Set the legend of the figure
plt.legend(["Original","SMA20","SMA50","SMA100"])

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX
plt.figure()
df["close"].plot()

# Overlay STD20, STD50, and STD100 on the same figure
df.rolling(window=20).std()["close"].plot()
df.rolling(window=50).std()["close"].plot()
df.rolling(window=100).std()["close"].plot()

# Set the legend of the figure
plt.legend(["Original","SMA20_std","SMA50_std","SMA100_std"])

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?

# %% [markdown]
# *The risk increases in the long run, while returns also increase, so we should compute risk adjusted metrics to determine the viability of NFLX in the long run*
